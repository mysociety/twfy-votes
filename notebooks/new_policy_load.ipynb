# %%
# This notebook imports legacy publicwhip policy information into yaml files that power new database

from pathlib import Path
import os
import re
import pandas as pd
from datetime import date

while not (Path.cwd() / "pyproject.toml").exists():
    os.chdir("..")

from twfy_votes.internal.db import duck_core
from twfy_votes.apps.legacy.data_sources import duck as tables_duck
from twfy_votes.apps.policies.models import (
    PolicyDirection,
    PartialPolicy,
    PolicyStrength,
    PartialDivision,
    PartialPolicyDecisionLink,
    PolicyStatus,
    PolicyGroup,
    StrengthMeaning,
)

duck = await duck_core.get_core()

await duck.compile(tables_duck).run()

# %%
query = """
select dream_id as id, description as policy_description from pw_dyn_dreammp
"""

full_desc_df = await duck.compile(query).df()

# %%
query = """
select * from pw_dyn_dreamvote order by dream_id, house, division_date, division_number
"""


def get_direction(s: str) -> PolicyDirection:
    match s:
        case "aye" | "aye3":
            return PolicyDirection.AGREE
        case "no" | "no3":
            return PolicyDirection.AGAINST
        case "both":
            return PolicyDirection.NEUTRAL
        case _:
            raise ValueError(f"Unknown vote direction {s}")


def get_strength(s: str) -> PolicyStrength:
    match s:
        case "aye" | "no" | "both":
            return PolicyStrength.WEAK
        case "aye3" | "no3":
            return PolicyStrength.STRONG
        case _:
            raise ValueError(f"Unknown vote strength {s}")


def get_partial(s: pd.Series) -> PartialDivision:
    return PartialDivision(
        chamber_slug=s["house"],
        date=s["division_date"],
        division_number=int(s["division_number"]),
    )


def get_links(s: pd.Series) -> PartialPolicyDecisionLink:
    return PartialPolicyDecisionLink(
        division=s["partial_division"], alignment=s["direction"], strength=s["strength"]
    )


votes_df = await duck.compile(query).df()
votes_df["direction"] = votes_df["vote"].apply(get_direction)
votes_df["strength"] = votes_df["vote"].apply(get_strength)
votes_df["partial_division"] = votes_df.apply(get_partial, axis=1)
votes_df["links"] = votes_df.apply(get_links, axis=1)

# create a dict vote_lookup that maps from dream_id to a list of PolicyDivisionLink objects

vote_lookup = votes_df.groupby("dream_id").agg({"links": list}).to_dict()["links"]

# %%
df = pd.read_csv(Path("data", "raw", "proposed_policies_2023.csv"))  # type: ignore


def fix_wording(s: str) -> str:
    # split on new line and only get first line
    s = s.split("\n")[0]
    # remove '[MP name] generally voted for more '
    s = s.replace("[MP name] generally voted for ", "").strip()
    # replace **, ** with open and close bold tags
    s = re.sub(r"\*\*(.*?)\*\*", r"<b>\1</b>", s)
    return s


df["candidate_wording"] = df["candidate_wording"].apply(fix_wording)


def get_group_ids(s: str) -> list[PolicyGroup]:
    descs = s.split("|")

    desc_to_item = {y: x for x, y in PolicyGroup.policy_descs.items()}
    return [desc_to_item[x] for x in descs]


df["group_ids"] = df["group"].apply(get_group_ids)

df
# Out:
#     policy_id                                              title  \
# 0         856                     Powers of Government Ministers
# 1        6917                              Powers of the Monarch
# 2        6788  Increase the State Pension Age for Women More ...
# 3        6971          Suspending MPs or Reducing their Salaries
# 4        6789  Powers of the Devolved Administration in North...
# 5        6831                                  Employment rights
# 6        6844                                   Child Protection
# 7        6852                                         Sentencing
# 8        6854                                        Fire Safety
# 9        6885      Support for Small and Medium Sized Businesses
# 10       6845        Support for Marriage and Civil Partnerships
# 11       6851                       Standards for Imported Goods
# 12       6857     Free Internal Market Within the United Kingdom
# 13       6958  The Republic of Ireland - Northern Ireland Border
# 14       6859                   International Treaty Obligations
# 15       6861           Free School Meals During School Holidays
# 16       6862                                       Planning Law
# 17       6868  Authorised Criminal Conduct by Undercover Sources
# 18       6881                                Consumer Protection
# 19       6887                                       Biodiversity
# 20       6888                                        Air Quality
# 21       6892  Protecting Tenants and Leaseholders from Costs...
# 22       6893                 Income Tax - Higher Rate Threshold
# 23       6894  Role of Politicians in Determining When a Pris...
# 24       6897                                  State Pension Age
# 25       6899            Regulation and Transparency of Lobbying
# 26       6901         Protecting and Supporting Victims of Crime
# 27       6902                           Higher Wages for Workers
# 28       6903                               Digital Services Tax
# 29        852                                      Nuclear Power
# 30       6910                                       Court Delays
# 31       6916  Removal of Trespassers Intending to Reside on ...
# 32       6919  Trials of Military Personnel in Civilian Court...
# 33       6920                 Coordinated Health and Social Care
# 34       6921        Virginity Checking and Hymen Reconstruction
# 35       6922       Removal of Asylum Seekers to Other Countries
# 36       6923                                    Overseas Voters
# 37       6793                               Voter Identification
# 38       6925  Higher Taxes Specifically to Fund Health and Care
# 39       6821               Experimental Trials to Inform Policy
# 40       6818           Referendum on EU Withdrawal Arrangements
# 41       6812                                         Free Trade
# 42       6804                           More Anti-Terrorism Laws
# 43       6954  Crimes Motivated by Hostility Towards Sex or G...
# 44       6956                            International Sanctions
# 45       6961  Sale and Advertising of Tobacco and Other Nico...
# 46       6909  Hydraulic Fracturing (Fracking) to Extract Sha...
# 47       6963      Individual Contributions to Social Care Costs
# 48       6965                         Deprivation of Citizenship
# 49       6869                                        Immigration
# 50       6967                                 Access to Abortion
# 51        629                      Protesting Outside Parliament
# 52       6915                               The Right to Protest
# 53       6928                        Environmental Water Quality
# 54       6866    Support for the Economy in Response to COVID-19
# 55       6860            Action to Reduce the Spread of COVID-19
# 56       6802                         Heathrow Airport Expansion
# 57       6766  Preservation of Environmental Protections on W...
# 58        863  Strengthening the Role of MPs in the House of ...
# 59       6780                          Openness and Transparency
#
#                              group     status  \
# 0            Constitutional Reform      draft
# 1            Constitutional Reform   rejected
# 2   Welfare, Benefits and Pensions  candidate
# 3             Miscellaneous Topics      draft
# 4            Constitutional Reform  candidate
# 5          Taxation and Employment   rejected
# 6                     Home Affairs   rejected
# 7                          Justice   rejected
# 8                          Housing  candidate
# 9         Business and the Economy   rejected
# 10                   Social Issues      draft
# 11        Business and the Economy  candidate
# 12            Miscellaneous Topics  candidate
# 13            Miscellaneous Topics      draft
# 14      Foreign Policy and Defence  candidate
# 15                       Education   rejected
# 16                         Housing  candidate
# 17                    Home Affairs  candidate
# 18        Business and the Economy   rejected
# 19            Environmental Issues  candidate
# 20            Environmental Issues  candidate
# 21                         Housing  candidate
# 22         Taxation and Employment      draft
# 23                         Justice   rejected
# 24  Welfare, Benefits and Pensions  candidate
# 25           Constitutional Reform   rejected
# 26                    Home Affairs      draft
# 27         Taxation and Employment   rejected
# 28        Business and the Economy      draft
# 29            Environmental Issues  candidate
# 30                         Justice      draft
# 31                    Home Affairs  candidate
# 32            Miscellaneous Topics      draft
# 33                          Health   rejected
# 34                   Social Issues   rejected
# 35                    Home Affairs   rejected
# 36           Constitutional Reform   rejected
# 37           Constitutional Reform      draft
# 38  Taxation and Employment|Health  candidate
# 39            Miscellaneous Topics   rejected
# 40      Foreign Policy and Defence  candidate
# 41        Business and the Economy  candidate
# 42            Miscellaneous Topics      draft
# 43                    Home Affairs      draft
# 44      Foreign Policy and Defence   rejected
# 45                          Health      draft
# 46            Environmental Issues      draft
# 47                          Health  candidate
# 48                    Home Affairs  candidate
# 49                    Home Affairs   rejected
# 50                          Health  candidate
# 51                    Home Affairs   rejected
# 52                    Home Affairs  candidate
# 53            Environmental Issues  candidate
# 54        Business and the Economy      draft
# 55                          Health  candidate
# 56                       Transport  candidate
# 57            Environmental Issues  candidate
# 58           Constitutional Reform   rejected
# 59            Miscellaneous Topics      draft
#
#                                     candidate_wording  \
# 0         more <b>powers for government ministers</b>
# 1                  more <b>powers for the monarch</b>
# 2   <b>increasing the state pension age for women ...
# 3   <b>suspending MPs or reducing their salaries</...
# 4   <b>more powers for</b> the devolved administra...
# 5                            <b>employment rights</b>
# 6                    <b>child protection</b> measures
# 7                 <b>tougher sentences for crimes</b>
# 8                         <b>fire safety measures</b>
# 9   support for <b>small and medium sized business...
# 10  supporting <b>marriage and civil partnerships</b>
# 11  requiring <b>imported goods</b> to meet <b>dom...
# 12  the <b>free movement</b> of goods, and mutual ...
# 13  <b>avoiding physical infrastructure at the bor...
# 14  fulfilling <b>international treaty obligations...
# 15  the provision of <b>free school meals</b> to e...
# 16              more <b>restrictive planning laws</b>
# 17  authorising <b>criminal conduct by undercover ...
# 18                    <b>consumer protection</b> laws
# 19                      improving <b>biodiversity</b>
# 20                       improving <b>air quality</b>
# 21  <b>protecting tenants and leaseholders from th...
# 22  raising the threshold at which people start to...
# 23  a greater <b>role for politicians in determini...
# 24            <b>increasing the state pension age</b>
# 25  <b>greater regulation and transparency of lobb...
# 26  <b>protecting and supporting victims of crime</b>
# 27                    <b>higher wages for workers</b>
# 28  <b>higher taxes</b> on the providers of major ...
# 29                               <b>nuclear power</b>
# 30                       <b>reducing court delays</b>
# 31  making it easier to <b>remove those trespassin...
# 32  <b>putting military personnel on trial in civi...
# 33          <b>coordinated Health and Social Care</b>
# 34  <b>a ban on virginity testing and hymen recons...
# 35  <b>removing asylum-seekers to other countries<...
# 36  allowing more <b>British citizens who live ove...
# 37  <b>photographic voter identification at pollin...
# 38  <b>higher taxes specifically to fund health an...
# 39  <b>experimental trials to inform policy decisi...
# 40  a <b>referendum on the terms of the UK's withd...
# 41                                  <b>free trade</b>
# 42                    <b>more anti-terrorism laws</b>
# 43  <b>treating crimes motivated by hostility towa...
# 44                     <b>international sanctions</b>
# 45  <b>restricting</b> the sale and advertising of...
# 46  <b>hydraulic fracturing (fracking)</b> to extr...
# 47  <b>reducing</b> the maximum amount an individu...
# 48  making it easier to <b>remove someone's Britis...
# 49               a <b>stricter immigration system</b>
# 50                   easier <b>access to abortion</b>
# 51  restricting the <b>right to protest</b> outsid...
# 52            restricting the <b>right to protest</b>
# 53       improving <b>environmental water quality</b>
# 54  more <b>support for the economy</b> in respons...
# 55     action to reduce the spread of <b>COVID-19</b>
# 56   adding a <b>third runway at Heathrow Airport</b>
# 57  the explicit <b>preservation of environmental ...
# 58  <b>strengthening the role of MPs</b> in the Ho...
# 59                  <b>openness and transparency</b>.
#
#                                                  desc           group_ids
# 0   There have been votes in Parliament on whether Gove...            [reform]
# 1   There have been votes in Parliament on whether the ...            [reform]
# 2   There have been votes in Parliament on the spe...           [welfare]
# 3   There have been votes in Parliament on whether to s...              [misc]
# 4   There have been votes in Parliament on the pow...            [reform]
# 5   There have been votes in Parliament on making ...          [taxation]
# 6   There have been votes in Parliament on protect...              [home]
# 7   There have been votes in Parliament on the max...           [justice]
# 8   There have been votes in Parliament on fire sa...           [housing]
# 9   There have been votes in Parliament on specifi...          [business]
# 10  There have been votes in Parliament on support...            [social]
# 11  There have been votes in Parliament on whether the ...          [business]
# 12  There have been votes in Parliament on the fre...              [misc]
# 13  There have been votes in Parliament which woul...              [misc]
# 14  There have been votes in Parliament on the ful...     [foreignpolicy]
# 15  There have been votes in Parliament on whether meal...         [education]
# 16  There have been votes in Parliament on whether plan...           [housing]
# 17  There have been votes in Parliament on procedu...              [home]
# 18  There have been votes in Parliament on improvi...          [business]
# 19  There have been votes in Parliament on the wei...       [environment]
# 20  There have been votes in Parliament on the wei...       [environment]
# 21  There have been votes in Parliament on prevent...           [housing]
# 22  There have been votes in Parliament on the inc...          [taxation]
# 23  There have been votes in Parliament on whether to e...           [justice]
# 24  There have been votes in Parliament on increas...           [welfare]
# 25  There have been votes in Parliament on introdu...            [reform]
# 26  There have been votes in Parliament on providi...              [home]
# 27  There have been votes in Parliament on introdu...          [taxation]
# 28  There have been votes in Parliament on introdu...          [business]
# 29  There have been votes in Parliament on whether to s...       [environment]
# 30  There have been votes in Parliament on measure...           [justice]
# 31  There have been votes in Parliament on the cir...              [home]
# 32  There have been votes in Parliament on whether to r...              [misc]
# 33  There have been votes in Parliament on a Bill ...            [health]
# 34  There have been votes in Parliament on a Bill ...            [social]
# 35  There have been votes in Parliament on whether to p...              [home]
# 36  There have been votes in Parliament on allowin...            [reform]
# 37  There have been votes in Parliament on introdu...            [reform]
# 38  There have been votes in Parliament on a "Heal...  [taxation, health]
# 39  There have been votes in Parliament on whether tria...              [misc]
# 40  There have been votes in Parliament on whether a re...     [foreignpolicy]
# 41  There have been votes in Parliament on the Uni...          [business]
# 42  There have been votes in Parliament on new and...              [misc]
# 43  There have been votes in Parliament on whether to t...              [home]
# 44  There have been votes in Parliament on pursuin...     [foreignpolicy]
# 45  There have been votes in Parliament on regulat...            [health]
# 46  Parliament has voted on whether hydraulic frac...       [environment]
# 47  There have been votes in Parliament both on th...            [health]
# 48  Certain individuals may be have their British ...              [home]
# 49  There have been votes in Parliament on the Uni...              [home]
# 50  There have been votes in Parliament on the cir...            [health]
# 51  There have been votes in Parliament on restric...              [home]
# 52  There have been recent votes in Parliament on ...              [home]
# 53  There have been votes in Parliament on reducin...       [environment]
# 54  There have been votes in Parliament on support...          [business]
# 55  Parliament voted on laws intended to the sprea...            [health]
# 56  There have been votes in Parliament on expandi...         [transport]
# 57  There have been votes in Parliament on the ret...       [environment]
# 58  There have been votes in Parliament on whether...            [reform]
# 59  Parliament has voted on access to information ...              [misc]

# %%
policies: list[PartialPolicy] = []

for _, row in df.iterrows():
    if row["status"] == "rejected":
        continue
    policy = PartialPolicy(
        chamber_id="commons",
        status=row["status"],
        strength_meaning=StrengthMeaning.CLASSIC,
        id=row["policy_id"],
        name=row["title"],
        context_description=row["candidate_wording"],
        highlightable=False,
        policy_description=row["desc"],
        group_ids=row["group_ids"],
        decision_links_refs=vote_lookup[row["policy_id"]],
    )
    policies.append(policy)

# %%
print(policy)
# Out:
# id=6780 name='Openness and Transparency' chamber_id='commons' context_description='<b>openness and transparency</b>.' policy_description="Parliament has voted on access to information laws, and occasionally on whether specific material should be published. There have also been votes on what information companies must disclose as well as on the transparency of our political system, including representatives' interests, allowances and expenses." notes='' status='draft' group_ids=['misc'] strength_meaning='classic' highlightable=False decision_links_refs=[PartialPolicyDecisionLink(division=PartialDivision(chamber_slug='commons', date=datetime.date(1999, 12, 7), division_number=12, key='commons-1999-12-07-12'), agreement=None, alignment='against', strength='strong', status='active', notes='', decision_type='division', decision_key='commons-1999-12-07-12'), PartialPolicyDecisionLink(division=PartialDivision(chamber_slug='commons', date=datetime.date(1999, 12, 7), division_number=13, key='commons-1999-12-07-13'), agreement=None, alignment='neutral', strength='weak', status='active', notes='', decision_type='division', decision_key='commons-1999-12-07-13'), PartialPolicyDecisionLink(division=PartialDivision(chamber_slug='commons', date=datetime.date(2000, 4, 4), division_number=142, key='commons-2000-04-04-142'), agreement=None, alignment='agree', strength='strong', status='active', notes='', decision_type='division', decision_key='commons-2000-04-04-142'), PartialPolicyDecisionLink(division=PartialDivision(chamber_slug='commons', date=datetime.date(2000, 4, 4), division_number=143, key='commons-2000-04-04-143'), agreement=None, alignment='against', strength='weak', status='active', notes='', decision_type='division', decision_key='commons-2000-04-04-143'), PartialPolicyDecisionLink(division=PartialDivision(chamber_slug='commons', date=datetime.date(2000, 4, 5), division_number=144, key='commons-2000-04-05-144'), agreement=None, alignment='agree', strength='strong', status='active', notes='', decision_type='division', decision_key='commons-2000-04-05-144'), PartialPolicyDecisionLink(division=PartialDivision(chamber_slug='commons', date=datetime.date(2000, 4, 5), division_number=145, key='commons-2000-04-05-145'), agreement=None, alignment='neutral', strength='weak', status='active', notes='', decision_type='division', decision_key='commons-2000-04-05-145'), PartialPolicyDecisionLink(division=PartialDivision(chamber_slug='commons', date=datetime.date(2000, 4, 5), division_number=146, key='commons-2000-04-05-146'), agreement=None, alignment='agree', strength='strong', status='active', notes='', decision_type='division', decision_key='commons-2000-04-05-146'), PartialPolicyDecisionLink(division=PartialDivision(chamber_slug='commons', date=datetime.date(2000, 4, 5), division_number=147, key='commons-2000-04-05-147'), agreement=None, alignment='agree', strength='strong', status='active', notes='', decision_type='division', decision_key='commons-2000-04-05-147'), PartialPolicyDecisionLink(division=PartialDivision(chamber_slug='commons', date=datetime.date(2000, 4, 5), division_number=148, key='commons-2000-04-05-148'), agreement=None, alignment='agree', strength='strong', status='active', notes='', decision_type='division', decision_key='commons-2000-04-05-148'), PartialPolicyDecisionLink(division=PartialDivision(chamber_slug='commons', date=datetime.date(2000, 4, 5), division_number=149, key='commons-2000-04-05-149'), agreement=None, alignment='agree', strength='strong', status='active', notes='', decision_type='division', decision_key='commons-2000-04-05-149'), PartialPolicyDecisionLink(division=PartialDivision(chamber_slug='commons', date=datetime.date(2000, 4, 5), division_number=150, key='commons-2000-04-05-150'), agreement=None, alignment='agree', strength='strong', status='active', notes='', decision_type='division', decision_key='commons-2000-04-05-150'), PartialPolicyDecisionLink(division=PartialDivision(chamber_slug='commons', da ...

# %%
data_path = Path("data", "policies")
for x in policies:
    x.to_path(data_path / f"{x.id}.yml", x.model_dump_reduced())
